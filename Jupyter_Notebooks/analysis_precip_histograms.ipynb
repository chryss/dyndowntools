# %% [markdown]
# ### Imports & settings

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from pathlib import Path
import colorcet as cc
import calendar
import statsmodels.api as sm
from scipy import stats

# %%
datadir = Path().absolute().parent / "evaluation/working"
figdir = Path().absolute().parent / "evaluation/figures"
filepattern = 'precip_{airport}_1970_2020_{resolution}.csv'
filepattern_era5 = 'era5_{airport}_precip_1981_2020_monthly.csv'

# %%
stations = {
    "ANCHORAGE_TED_STEVENS_INTERNATIONAL_AIRPORT": "PANC",
    "FAIRBANKS_INTL_AP": "PAFA",
    "BARROW_AIRPORT": "PABR",
    "BETHEL_AIRPORT": "PABE"
}
startdate = '1981-01-01'
enddate = '2020-12-31'
fullnames = list(stations.keys())
resolutions = ['4km', '12km']

# %%
month_abbr = [calendar.month_abbr[ii] for ii in range(1, 13)]
month_initials = [item[0] for item in month_abbr]

# %%
teststation = fullnames[0]

(datadir / filepattern.format(airport=teststation, resolution=resolutions[0])).exists()
# Out:
# True

# %% [markdown]
# ### Functions

# %%
def get_dataframe(station, startdate=startdate, enddate=enddate):
    dfs = {}
    for res in resolutions:
        dfs[res] = pd.read_csv(
            datadir / filepattern.format(airport=station, resolution=res))
        dfs[res]['Time'] = pd.to_datetime(dfs[res]['Time'])
        # dfs[res].set_index('Time')
    dfs['4km']['precip_mm_ERA5_12km'] = dfs['12km']['precip_mm_ERA5_12km']
    new_order_indices = [0, 1, 4, 2, 3]
    return dfs['4km'].iloc[:, new_order_indices]

# %%
def get_label(location, variable):
    if variable==location:
        return stations[location.replace(' ', '_')]
    elif variable=='precip_mm_ERA5_12km':
        return 'ERA5-12km'
    elif variable=='precip_mm_ERA5_4km':
        return 'ERA5-4km'

# %%
def get_name(location):
    name = location.split(' ')[0].title()
    if name == 'Barrow':
        return 'Utqiaġvik'
    else:
        return name

# %%
def get_stats(location, monthlyDF):
    output = []
    for variable in (location, 'precip_mm_ERA5_12km', 'precip_mm_ERA5_4km'):
        for mth in range(1, 13):
            X = monthlyDF.query(f'month == {mth}')['year']
            Y = monthlyDF.query(f'month == {mth}')[variable]
            slope, _, r_value, p_value, _ = stats.linregress(X, Y)
            mean = Y.mean()
            output.append({
                "location": location.split(' ')[0].title(),
                'variable': get_label(location, variable),
                'month': mth, 
                'mean_monthly_mm': mean, 
                'trend': slope, 
                'p_value': p_value, 
                'r_value':r_value})
    return output

# %%
def get_monthly(dailyDF, location, 
                startdate=startdate, enddate=enddate):
    dailyDF = dailyDF.loc[startdate:enddate]
    monthly_sum = dailyDF[['precip_mm_ERA5_4km', 'precip_mm_ERA5_12km', location]].groupby(
        pd.Grouper(freq='M')).sum()
    monthly_sum['year'] = monthly_sum.index.year
    monthly_sum['month'] = monthly_sum.index.month
    return monthly_sum

# %%
def add_significance_suffix(p_value):
    if p_value < 0.05:
        return ' (**)'
    elif p_value < 0.1:
        return ' (*)'
    else: return ''

# %% [markdown]
# ### Single location prototyping

# %%
compDF = get_dataframe(teststation)
compDF.index
# Out:
# RangeIndex(start=0, stop=18628, step=1)

# %%
compDF
# Out:
#             Time  precip_mm_ERA5_4km  precip_mm_ERA5_12km  \
# 0     1970-01-01               0.017                0.021
# 1     1970-01-02               0.193                0.189
# 2     1970-01-03               0.068                0.046
# 3     1970-01-04               0.000                0.000
# 4     1970-01-05               0.000                0.000
# ...          ...                 ...                  ...
# 18623 2020-12-27               0.143                0.352
# 18624 2020-12-28               0.121                0.441
# 18625 2020-12-29               0.243                0.099
# 18626 2020-12-30               2.271                2.208
# 18627 2020-12-31               0.365                0.646
#
#        ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT month
# 0                                            2.286   Jan
# 1                                            0.254   Jan
# 2                                            0.000   Jan
# 3                                            0.000   Jan
# 4                                            0.000   Jan
# ...                                            ...   ...
# 18623                                        0.000   Dec
# 18624                                        1.524   Dec
# 18625                                        0.000   Dec
# 18626                                        0.000   Dec
# 18627                                        0.000   Dec
#
# [18628 rows x 5 columns]

# %%
compDF = get_dataframe(teststation)
location = teststation.replace('_', ' ')
compDF.set_index('Time', inplace=True)
compDF = compDF.loc[startdate:enddate]
monthly_sum = compDF[['precip_mm_ERA5_4km', 'precip_mm_ERA5_12km', location]].groupby(
    pd.Grouper(freq='M')
).sum()
monthly_sum
# Out:
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/1784742218.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')
#             precip_mm_ERA5_4km  precip_mm_ERA5_12km  \
# Time
# 1981-01-31              39.429               53.396
# 1981-02-28              42.878               53.372
# 1981-03-31              23.238               34.443
# 1981-04-30               9.282                8.222
# 1981-05-31              52.988               49.222
# ...                        ...                  ...
# 2020-08-31              81.637               85.504
# 2020-09-30              87.973               97.275
# 2020-10-31              50.861               52.519
# 2020-11-30              58.428               83.535
# 2020-12-31              42.321               46.545
#
#             ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT
# Time
# 1981-01-31                                       25.654
# 1981-02-28                                       26.670
# 1981-03-31                                       11.938
# 1981-04-30                                        5.842
# 1981-05-31                                       22.606
# ...                                                 ...
# 2020-08-31                                       82.804
# 2020-09-30                                       49.276
# 2020-10-31                                       39.116
# 2020-11-30                                       40.894
# 2020-12-31                                       39.878
#
# [480 rows x 3 columns]

# %%
monthly_sum['year'] = monthly_sum.index.year
monthly_sum['month'] = monthly_sum.index.month
monthly_sum
# Out:
#             precip_mm_ERA5_4km  precip_mm_ERA5_12km  \
# Time
# 1981-01-31              39.429               53.396
# 1981-02-28              42.878               53.372
# 1981-03-31              23.238               34.443
# 1981-04-30               9.282                8.222
# 1981-05-31              52.988               49.222
# ...                        ...                  ...
# 2020-08-31              81.637               85.504
# 2020-09-30              87.973               97.275
# 2020-10-31              50.861               52.519
# 2020-11-30              58.428               83.535
# 2020-12-31              42.321               46.545
#
#             ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT  year  month
# Time
# 1981-01-31                                       25.654  1981      1
# 1981-02-28                                       26.670  1981      2
# 1981-03-31                                       11.938  1981      3
# 1981-04-30                                        5.842  1981      4
# 1981-05-31                                       22.606  1981      5
# ...                                                 ...   ...    ...
# 2020-08-31                                       82.804  2020      8
# 2020-09-30                                       49.276  2020      9
# 2020-10-31                                       39.116  2020     10
# 2020-11-30                                       40.894  2020     11
# 2020-12-31                                       39.878  2020     12
#
# [480 rows x 5 columns]

# %%
get_stats(location, monthly_sum)
# Out:
# [{'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 1,
#   'mean_monthly_mm': 20.999450000000003,
#   'trend': 0.19026172607879926,
#   'p_value': 0.23343829038727446,
#   'r_value': 0.19273939881777502},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 2,
#   'mean_monthly_mm': 22.15515,
#   'trend': 0.29519756097560973,
#   'p_value': 0.10625497420052187,
#   'r_value': 0.25922749922064714},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 3,
#   'mean_monthly_mm': 17.7927,
#   'trend': 0.2518078799249531,
#   'p_value': 0.10308669108569152,
#   'r_value': 0.2615217314309087},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 4,
#   'mean_monthly_mm': 13.296899999999999,
#   'trend': 0.10422101313320822,
#   'p_value': 0.4680459413736727,
#   'r_value': 0.11807921288915067},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 5,
#   'mean_monthly_mm': 19.69135,
#   'trend': -0.07279268292682932,
#   'p_value': 0.6570555330031476,
#   'r_value': -0.07240337967277746},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 6,
#   'mean_monthly_mm': 27.463750000000005,
#   'trend': 0.10662757973733583,
#   'p_value': 0.6199110091647899,
#   'r_value': 0.08085610263667416},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 7,
#   'mean_monthly_mm': 47.447199999999995,
#   'trend': 0.07505628517823637,
#   'p_value': 0.8348680698207162,
#   'r_value': 0.034030347145885126},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 8,
#   'mean_monthly_mm': 80.1751,
#   'trend': -0.5526048780487803,
#   'p_value': 0.42063346379979794,
#   'r_value': -0.13093508755182917},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 9,
#   'mean_monthly_mm': 80.0481,
#   'trend': 0.26191069418386503,
#   'p_value': 0.6717072774352811,
#   'r_value': 0.06912120185392098},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 10,
#   'mean_monthly_mm': 52.48274999999999,
#   'trend': -0.45307786116322724,
#   'p_value': 0.18732989623769195,
#   'r_value': -0.2128271612591382},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 11,
#   'mean_monthly_mm': 31.146749999999997,
#   'trend': 0.11992326454033769,
#   'p_value': 0.661961731477124,
#   'r_value': 0.07130124636395799},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 12,
#   'mean_monthly_mm': 31.115,
#   'trend': 0.22678911819887432,
#   'p_value': 0.32055517844552417,
#   'r_value': 0.16113754744350353},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 1,
#   'mean_monthly_mm': 47.0274,
#   'trend': -0.13012682926829264,
#   'p_value': 0.6933204058043976,
#   'r_value': -0.06432787543728133},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 2,
#   'mean_monthly_mm': 41.0292,
#   'trend': 0.2905917448405254,
#   'p_value': 0.27249770190004935,
#   'r_value': 0.17775324536361023},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 3,
#   'mean_monthly_mm': 36.698975000000004,
#   'trend': -0.2030847091932458,
#   'p_value': 0.46989895522407454,
#   'r_value': -0.11759144983737238},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 4,
#   'mean_monthly_mm': 34.8418,
#   'trend': 0.24393958724202633,
#   'p_value': 0.40862709124111785,
#   'r_value': 0.13431703805239695},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 5,
#   'mean_monthly_mm': 34.588225,
#   'trend': -0.2279306754221388,
#   'p_value': 0.29768283348883845,
#   'r_value': -0.16883011903693174},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 6,
#   'mean_monthly_mm': 43.534725,
#   'trend': 0.049792401500938124,
#   'p_value': 0.8725231211512241,
#   'r_value': 0.026196427641036676},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 7,
#   'mean_monthly_mm': 61.16265,
#   'trend': 0.31984521575985,
#   'p_value': 0.3339673488643585,
#   'r_value': 0.1567864491270712},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 8,
#   'mean_monthly_mm': 99.00725,
#   'trend': -0.4228080675422139,
#   'p_value': 0.5264143718788262,
#   'r_value': -0.10316700103789815},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 9,
#   'mean_monthly_mm': 101.434575,
#   'trend': 0.16562166979362092,
#   'p_value': 0.7644243397142275,
#   'r_value': 0.048905359727667776},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 10,
#   'mean_monthly_mm': 86.2046,
#   'trend': -0.46714090056285174,
#   'p_value': 0.33141816330757146,
#   'r_value': -0.15760495643070205},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 11,
#   'mean_monthly_mm': 61.361225000000005,
#   'trend': 0.3979933395872418,
#   'p_value': 0.44572939463679895,
#   'r_value': 0.12403685307566308},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 12,
#   'mean_monthly_mm': 59.9597,
#   'trend': -0.029381988742964327,
#   'p_value': 0.9335122456882371,
#   'r_value': -0.013622287155188996},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 1,
#   'mean_monthly_mm': 43.6414,
#   'trend': -0.07093076923076927,
#   'p_value': 0.8003065513019523,
#   'r_value': -0.04128714018378588},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 2,
#   'mean_monthly_mm': 38.7344,
#   'trend': 0.2555836772983114,
#   'p_value': 0.32878341455828775,
#   'r_value': 0.15845505363973114},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 3,
#   'mean_monthly_mm': 34.252475,
#   'trend': -0.020722045028142573,
#   'p_value': 0.9337759087935299,
#   'r_value': -0.013568147014440242},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 4,
#   'mean_monthly_mm': 33.81345,
#   'trend': 0.18995891181988747,
#   'p_value': 0.47513956474709684,
#   'r_value': 0.11621746932343835},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 5,
#   'mean_monthly_mm': 36.678399999999996,
#   'trend': -0.2743223264540337,
#   'p_value': 0.25605488885026034,
#   'r_value': -0.1838745615460258},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 6,
#   'mean_monthly_mm': 46.012125000000005,
#   'trend': -0.021675328330206425,
#   'p_value': 0.9443526291859491,
#   'r_value': -0.011397459650832291},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 7,
#   'mean_monthly_mm': 63.332674999999995,
#   'trend': 0.31389803001876176,
#   'p_value': 0.35238425635369364,
#   'r_value': 0.15098425931625056},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 8,
#   'mean_monthly_mm': 99.6436,
#   'trend': -0.42564652908067535,
#   'p_value': 0.5434785791150742,
#   'r_value': -0.09896575218557575},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 9,
#   'mean_monthly_mm': 100.4777,
#   'trend': 0.2503454033771106,
#   'p_value': 0.65794576776823,
#   'r_value': 0.07220316137125896},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 10,
#   'mean_monthly_mm': 82.1584,
#   'trend': -0.25347298311444644,
#   'p_value': 0.5714311625819477,
#   'r_value': -0.0922169287376513},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 11,
#   'mean_monthly_mm': 55.61195,
#   'trend': 0.2911981238273921,
#   'p_value': 0.523082379034662,
#   'r_value': 0.10399504725153522},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 12,
#   'mean_monthly_mm': 54.830724999999994,
#   'trend': -0.09429108818011257,
#   'p_value': 0.7766157174166737,
#   'r_value': -0.04630628698458703}]

# %%
output = []
for mth in range(1, 13):
    X = monthly_sum.query(f'month == {mth}')['year']
    Y = monthly_sum.query(f'month == {mth}')[location]
    slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
    mean = Y.mean()
    output.append((mth, mean, slope, p_value, r_value, std_err))

# %%
output
# Out:
# [(1,
#   20.999450000000003,
#   0.19026172607879926,
#   0.23343829038727446,
#   0.19273939881777502,
#   0.15713350400325285),
#  (2,
#   22.15515,
#   0.29519756097560973,
#   0.10625497420052187,
#   0.25922749922064714,
#   0.17841625614705298),
#  (3,
#   17.7927,
#   0.2518078799249531,
#   0.10308669108569152,
#   0.2615217314309087,
#   0.15075994256683115),
#  (4,
#   13.296899999999999,
#   0.10422101313320822,
#   0.4680459413736727,
#   0.11807921288915067,
#   0.14218085418217805),
#  (5,
#   19.69135,
#   -0.07279268292682932,
#   0.6570555330031476,
#   -0.07240337967277746,
#   0.16266561338371097),
#  (6,
#   27.463750000000005,
#   0.10662757973733583,
#   0.6199110091647899,
#   0.08085610263667416,
#   0.2132262371125457),
#  (7,
#   47.447199999999995,
#   0.07505628517823637,
#   0.8348680698207162,
#   0.034030347145885126,
#   0.3575833360509979),
#  (8,
#   80.1751,
#   -0.5526048780487803,
#   0.42063346379979794,
#   -0.13093508755182917,
#   0.678753090863122),
#  (9,
#   80.0481,
#   0.26191069418386503,
#   0.6717072774352811,
#   0.06912120185392098,
#   0.613211361713032),
#  (10,
#   52.48274999999999,
#   -0.45307786116322724,
#   0.18732989623769195,
#   -0.2128271612591382,
#   0.3374337344964198),
#  (11,
#   31.146749999999997,
#   0.11992326454033769,
#   0.661961731477124,
#   0.07130124636395799,
#   0.27214963673670733),
#  (12,
#   31.115,
#   0.22678911819887432,
#   0.32055517844552417,
#   0.16113754744350353,
#   0.22533096530874705)]

# %%
mth = 8
X = monthly_sum.query(f'month == {mth}')['year']
Y = monthly_sum.query(f'month == {mth}')[location]
slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)

# %%
slope, intercept, p_value
# Out:
# (-0.5526048780487803, 1185.661158536585, 0.42063346379979794)

# %%
cmap = plt.cm.get_cmap('cet_glasbey')
cmap = plt.cm.get_cmap('Set1')
# Out:
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/1137458020.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('cet_glasbey')
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/1137458020.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('Set1')

# %%
df_forplot = pd.melt(monthly_sum.reset_index(), id_vars=[monthly_sum.index.name, 'year', 'month'], 
        value_vars=['precip_mm_ERA5_4km', 'precip_mm_ERA5_12km', location], value_name='precip_mm', var_name='dataseries')

# %%
palette = sns.color_palette(cc.b_glasbey_category10, n_colors=3)
palette = sns.color_palette("Set2", 10)
palette[3] = palette[7]
palette = palette[:4]
palette
# viridis_palette = sns.color_palette("viridis", 25)
# viridis_palette = [viridis_palette[ii] for ii in [14, 8, -1]]
# viridis_palette
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
g = sns.catplot(data=df_forplot, kind="bar", x="month", y="precip_mm", 
            hue="dataseries", palette='Set2', width=0.85, height=3, aspect=2)
g._legend.remove()

# %%
g = sns.boxplot(data=df_forplot, x="month", y="precip_mm", 
            hue="dataseries", palette='Set2', legend=False, fliersize=3)
g.set_xticklabels(month_abbr)
g.set_xlabel('')
g.set_ylabel('total monthly precipitation [mm]')
# Out:
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/3042404769.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# Text(0, 0.5, 'total monthly precipitation [mm]')

# %%
g = sns.catplot(data=df_forplot, kind="violin", x="month", y="precip_mm", 
            hue="dataseries", palette=palette, height=3, aspect=4)

# %%
g = sns.catplot(data=df_forplot, kind="violin", x="month", y="precip_mm", 
            hue="dataseries", palette=palette, height=3, aspect=7)
g._legend.remove()

# %%
monthly_sum.drop(columns=['month', 'year']).groupby(monthly_sum.index.month).mean().plot(
    kind='bar', width=0.9, cmap='Set2')
# Out:
# <Axes: xlabel='Time'>

# %%
monthly_sum
# Out:
#             precip_mm_ERA5_4km  precip_mm_ERA5_12km  \
# Time
# 1981-01-31              39.429               53.396
# 1981-02-28              42.878               53.372
# 1981-03-31              23.238               34.443
# 1981-04-30               9.282                8.222
# 1981-05-31              52.988               49.222
# ...                        ...                  ...
# 2020-08-31              81.637               85.504
# 2020-09-30              87.973               97.275
# 2020-10-31              50.861               52.519
# 2020-11-30              58.428               83.535
# 2020-12-31              42.321               46.545
#
#             ANCHORAGE TED STEVENS INTERNATIONAL AIRPORT  year  month
# Time
# 1981-01-31                                       25.654  1981      1
# 1981-02-28                                       26.670  1981      2
# 1981-03-31                                       11.938  1981      3
# 1981-04-30                                        5.842  1981      4
# 1981-05-31                                       22.606  1981      5
# ...                                                 ...   ...    ...
# 2020-08-31                                       82.804  2020      8
# 2020-09-30                                       49.276  2020      9
# 2020-10-31                                       39.116  2020     10
# 2020-11-30                                       40.894  2020     11
# 2020-12-31                                       39.878  2020     12
#
# [480 rows x 5 columns]

# %%
get_stats(location, monthly_sum)
# Out:
# [{'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 1,
#   'mean_monthly_mm': 20.999450000000003,
#   'trend': 0.19026172607879932,
#   'p_value': 0.23343829038727423,
#   'r_value': 0.19273939881777508},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 2,
#   'mean_monthly_mm': 22.15515,
#   'trend': 0.29519756097560973,
#   'p_value': 0.10625497420052187,
#   'r_value': 0.25922749922064714},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 3,
#   'mean_monthly_mm': 17.7927,
#   'trend': 0.2518078799249531,
#   'p_value': 0.10308669108569161,
#   'r_value': 0.2615217314309086},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 4,
#   'mean_monthly_mm': 13.296899999999999,
#   'trend': 0.10422101313320822,
#   'p_value': 0.4680459413736727,
#   'r_value': 0.11807921288915067},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 5,
#   'mean_monthly_mm': 19.69135,
#   'trend': -0.07279268292682929,
#   'p_value': 0.6570555330031477,
#   'r_value': -0.07240337967277742},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 6,
#   'mean_monthly_mm': 27.463750000000005,
#   'trend': 0.10662757973733586,
#   'p_value': 0.6199110091647897,
#   'r_value': 0.08085610263667418},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 7,
#   'mean_monthly_mm': 47.447199999999995,
#   'trend': 0.07505628517823644,
#   'p_value': 0.834868069820716,
#   'r_value': 0.034030347145885154},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 8,
#   'mean_monthly_mm': 80.1751,
#   'trend': -0.5526048780487804,
#   'p_value': 0.4206334637997976,
#   'r_value': -0.1309350875518292},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 9,
#   'mean_monthly_mm': 80.0481,
#   'trend': 0.26191069418386503,
#   'p_value': 0.6717072774352811,
#   'r_value': 0.06912120185392098},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 10,
#   'mean_monthly_mm': 52.48274999999999,
#   'trend': -0.453077861163227,
#   'p_value': 0.1873298962376923,
#   'r_value': -0.21282716125913806},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 11,
#   'mean_monthly_mm': 31.146749999999997,
#   'trend': 0.11992326454033768,
#   'p_value': 0.661961731477124,
#   'r_value': 0.07130124636395799},
#  {'location': 'Anchorage',
#   'variable': 'PANC',
#   'month': 12,
#   'mean_monthly_mm': 31.115,
#   'trend': 0.22678911819887432,
#   'p_value': 0.3205551784455239,
#   'r_value': 0.1611375474435036},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 1,
#   'mean_monthly_mm': 47.0274,
#   'trend': -0.13012682926829264,
#   'p_value': 0.6933204058043976,
#   'r_value': -0.06432787543728133},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 2,
#   'mean_monthly_mm': 41.0292,
#   'trend': 0.29059174484052536,
#   'p_value': 0.27249770190004946,
#   'r_value': 0.1777532453636102},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 3,
#   'mean_monthly_mm': 36.698975000000004,
#   'trend': -0.2030847091932458,
#   'p_value': 0.46989895522407454,
#   'r_value': -0.11759144983737238},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 4,
#   'mean_monthly_mm': 34.8418,
#   'trend': 0.24393958724202627,
#   'p_value': 0.40862709124111785,
#   'r_value': 0.13431703805239695},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 5,
#   'mean_monthly_mm': 34.588225,
#   'trend': -0.2279306754221387,
#   'p_value': 0.2976828334888386,
#   'r_value': -0.16883011903693168},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 6,
#   'mean_monthly_mm': 43.534725,
#   'trend': 0.04979240150093811,
#   'p_value': 0.8725231211512241,
#   'r_value': 0.026196427641036673},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 7,
#   'mean_monthly_mm': 61.16265,
#   'trend': 0.3198452157598499,
#   'p_value': 0.3339673488643585,
#   'r_value': 0.15678644912707118},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 8,
#   'mean_monthly_mm': 99.00725,
#   'trend': -0.42280806754221395,
#   'p_value': 0.526414371878826,
#   'r_value': -0.10316700103789817},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 9,
#   'mean_monthly_mm': 101.434575,
#   'trend': 0.16562166979362092,
#   'p_value': 0.7644243397142275,
#   'r_value': 0.048905359727667776},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 10,
#   'mean_monthly_mm': 86.2046,
#   'trend': -0.4671409005628516,
#   'p_value': 0.3314181633075717,
#   'r_value': -0.157604956430702},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 11,
#   'mean_monthly_mm': 61.361225000000005,
#   'trend': 0.3979933395872419,
#   'p_value': 0.44572939463679895,
#   'r_value': 0.12403685307566309},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-12km',
#   'month': 12,
#   'mean_monthly_mm': 59.9597,
#   'trend': -0.029381988742964417,
#   'p_value': 0.9335122456882369,
#   'r_value': -0.013622287155189037},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 1,
#   'mean_monthly_mm': 43.6414,
#   'trend': -0.07093076923076924,
#   'p_value': 0.8003065513019525,
#   'r_value': -0.04128714018378586},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 2,
#   'mean_monthly_mm': 38.7344,
#   'trend': 0.25558367729831144,
#   'p_value': 0.32878341455828763,
#   'r_value': 0.15845505363973117},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 3,
#   'mean_monthly_mm': 34.252475,
#   'trend': -0.020722045028142625,
#   'p_value': 0.9337759087935298,
#   'r_value': -0.013568147014440271},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 4,
#   'mean_monthly_mm': 33.81345,
#   'trend': 0.18995891181988747,
#   'p_value': 0.47513956474709684,
#   'r_value': 0.11621746932343834},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 5,
#   'mean_monthly_mm': 36.678399999999996,
#   'trend': -0.2743223264540337,
#   'p_value': 0.2560548888502605,
#   'r_value': -0.18387456154602577},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 6,
#   'mean_monthly_mm': 46.012125000000005,
#   'trend': -0.021675328330206356,
#   'p_value': 0.9443526291859492,
#   'r_value': -0.011397459650832255},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 7,
#   'mean_monthly_mm': 63.332674999999995,
#   'trend': 0.31389803001876176,
#   'p_value': 0.35238425635369364,
#   'r_value': 0.15098425931625056},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 8,
#   'mean_monthly_mm': 99.6436,
#   'trend': -0.4256465290806754,
#   'p_value': 0.543478579115074,
#   'r_value': -0.09896575218557577},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 9,
#   'mean_monthly_mm': 100.4777,
#   'trend': 0.25034540337711064,
#   'p_value': 0.65794576776823,
#   'r_value': 0.07220316137125897},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 10,
#   'mean_monthly_mm': 82.1584,
#   'trend': -0.25347298311444655,
#   'p_value': 0.5714311625819476,
#   'r_value': -0.09221692873765135},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 11,
#   'mean_monthly_mm': 55.61195,
#   'trend': 0.29119812382739213,
#   'p_value': 0.5230823790346621,
#   'r_value': 0.10399504725153524},
#  {'location': 'Anchorage',
#   'variable': 'ERA5-4km',
#   'month': 12,
#   'mean_monthly_mm': 54.830724999999994,
#   'trend': -0.09429108818011256,
#   'p_value': 0.7766157174166737,
#   'r_value': -0.046306286984587025}]

# %% [markdown]
# ### Make all plots

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(13, 8), sharex=True)

results = []
for ii, (ax, station) in enumerate(zip(axes.flatten(), stations)):
    compDF = get_dataframe(station)
    location = station.replace('_', ' ')
    compDF.set_index('Time', inplace=True)
    monthly_sum = get_monthly(compDF, location, 
                              startdate=startdate, enddate=enddate)
    results.extend(get_stats(location, monthly_sum))
    df_forplot = pd.melt(monthly_sum.reset_index(), id_vars=[monthly_sum.index.name, 'year', 'month'], 
        value_vars=['precip_mm_ERA5_4km', 'precip_mm_ERA5_12km', location], value_name='precip_mm', var_name='dataseries')
    g = sns.boxplot(data=df_forplot, x="month", y="precip_mm", 
            hue="dataseries", palette="Set2", width=0.75, fliersize=3, ax=ax)
    ax.get_legend().remove()  
    g.set_xticklabels(month_abbr)
    if ii%2:
        g.set_ylabel('')
    else:
        g.set_ylabel('total monthly precipitation [mm]')
    g.set_xlabel('')
    ax.set_title('  ' + get_name(location), loc='left', y=0.9)
handles, _ = ax.get_legend_handles_labels()
labels = ['ERA5 - 4 km', 'ERA5 - 12 km', 'weather station']
fig.legend(handles, labels, loc='upper left', ncol=1, bbox_to_anchor=(0.06, 0.93), frameon=False)
plt.tight_layout()
    # g.fig.suptitle(location.split(' ')[0].title())
# Out:
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/1733566882.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/1733566882.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/1733566882.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/39/6h0p929579n8vrp25cjkbz3h0000gn/T/ipykernel_47839/1733566882.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)

# %%
fn = f"precip_stations_monthly_distribution_box_{startdate}-{enddate}.png"
fig.savefig(figdir / fn, bbox_inches='tight', dpi=300)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(13, 8), sharex=True)

results = []
for ax, station in zip(axes.flatten(), stations):
    compDF = get_dataframe(station)
    location = station.replace('_', ' ')
    compDF.set_index('Time', inplace=True)
    monthly_sum = get_monthly(compDF, location, 
                              startdate=startdate, enddate=enddate)
    df_forplot = pd.melt(monthly_sum.reset_index(), id_vars=[monthly_sum.index.name, 'month'], 
        value_vars=['precip_mm_ERA5_4km', 'precip_mm_ERA5_12km', location], value_name='precip_mm', var_name='dataseries')
    g = sns.barplot(data=df_forplot, x="month", y="precip_mm", 
            hue="dataseries", palette='Set1', width=0.8, ax=ax)  
    ax.get_legend().remove()  
    g.set_xticklabels(month_abbr)
    g.set_xlabel('')
    g.set_ylabel('total monthly precipitation [mm]')
    ax.set_title('  ' + get_name(location), loc='left', y=0.9)
handles, _ = ax.get_legend_handles_labels()
labels = ['ERA5 - 4 km', 'ERA5 - 12 km', 'weather station']
fig.legend(handles, labels, loc='upper left', ncol=1, bbox_to_anchor=(0.06, 0.93), frameon=False)

plt.tight_layout()
# Out:
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/3999468845.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/3999468845.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/3999468845.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/3999468845.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)

# %%
fn = f"precip_stations_monthly_distribution_bar_{startdate}-{enddate}.png"
fig.savefig(figdir / fn, bbox_inches='tight', dpi=300)

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10, 8), sharex=True)

for ax, station in zip(axes.flatten(), stations):
    compDF = get_dataframe(station)
    location = station.replace('_', ' ')
    compDF.set_index('Time', inplace=True)
    monthly_sum = get_monthly(compDF, location, 
                              startdate=startdate, enddate=enddate)
    df_forplot = pd.melt(monthly_sum.reset_index(), id_vars=[monthly_sum.index.name, 'month'], 
        value_vars=['precip_mm_ERA5_4km', 'precip_mm_ERA5_12km', location], value_name='precip_mm', var_name='dataseries')
    g = sns.violinplot(data=df_forplot, x="month", y="precip_mm", 
            hue="dataseries", palette=palette, ax=ax)  
    ax.get_legend().remove()  
    g.set_xticklabels(month_abbr)
    g.set_xlabel('')
    g.set_ylabel('')
    ax.set_title('  ' + get_name(location), loc='left', y=0.8)
handles, _ = ax.get_legend_handles_labels()
labels = ['ERA5 - 4 km', 'ERA5 - 12 km', 'weather station']
fig.supylabel('total monthly precip [mm]')
fig.legend(handles, labels, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 0.02), frameon=False)

plt.tight_layout()
# Out:
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/155049449.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/155049449.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/155049449.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/155049449.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(month_abbr)

# %%
fn = f"precip_stations_monthly_distribution_violin_{startdate}-{enddate}.png"
fig.savefig(figdir / fn, bbox_inches='tight', dpi=300)

# %%
results = []
for station in stations:
    compDF = get_dataframe(station)
    location = station.replace('_', ' ')
    compDF.set_index('Time', inplace=True)
    monthly_sum = get_monthly(compDF, location)

    results.extend(get_stats(location, monthly_sum))
# Out:
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/911239567.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.Grouper(freq='M')).sum()

# %%
resultsDF = pd.DataFrame.from_records(results)
resultsDF
# Out:
#       location  variable  month  mean_monthly_mm     trend   p_value   r_value
# 0    Anchorage      PANC      1        20.999450  0.190262  0.233438  0.192739
# 1    Anchorage      PANC      2        22.155150  0.295198  0.106255  0.259227
# 2    Anchorage      PANC      3        17.792700  0.251808  0.103087  0.261522
# 3    Anchorage      PANC      4        13.296900  0.104221  0.468046  0.118079
# 4    Anchorage      PANC      5        19.691350 -0.072793  0.657056 -0.072403
# ..         ...       ...    ...              ...       ...       ...       ...
# 139     Bethel  ERA5-4km      8        81.763975 -0.249162  0.553325 -0.096570
# 140     Bethel  ERA5-4km      9        75.575650 -0.389067  0.447444 -0.123573
# 141     Bethel  ERA5-4km     10        51.754975  0.434380  0.197895  0.207943
# 142     Bethel  ERA5-4km     11        55.950900 -0.089447  0.806944 -0.039888
# 143     Bethel  ERA5-4km     12        48.225525 -0.531167  0.043212 -0.321309
#
# [144 rows x 7 columns]

# %%
tableDF = resultsDF.query('variable != "ERA5-12km"')
tableDF['ID'] = tableDF.location + ': ' + tableDF['variable']
tableDF['strtrend'] = tableDF['trend'].round(2).astype(str) 
tableDF['sigtrend'] = tableDF['strtrend'] + tableDF['p_value'].apply(add_significance_suffix)
# Out:
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/611527881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableDF['ID'] = tableDF.location + ': ' + tableDF['variable']
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/611527881.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableDF['strtrend'] = tableDF['trend'].round(2).astype(str)
# /var/folders/jh/dmrl1jcn7ql6ftcyq7l6p8v80000gn/T/ipykernel_15342/611527881.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableDF['sigtrend'] = tableDF['strtrend'] + tableDF['p_value'].apply(add_significance_suffix)

# %%
sigtable = tableDF.pivot(index='ID', columns='month', values='sigtrend')
sigtable.columns = [calendar.month_abbr[ii] for ii in sigtable.columns]
sigtable
# Out:
#                        Jan        Feb       Mar      Apr        May  \
# ID
# Anchorage: ERA5-4km  -0.07       0.26     -0.02     0.19      -0.27
# Anchorage: PANC       0.19        0.3      0.25      0.1      -0.07
# Barrow: ERA5-4km     -0.03       0.08      0.11     0.05   0.22 (*)
# Barrow: PABR          0.09  0.18 (**)  0.2 (**)  0.1 (*)  0.23 (**)
# Bethel: ERA5-4km      -0.1  0.59 (**)     -0.21     0.32       0.14
# Bethel: PABE          0.07   0.44 (*)     -0.05      0.2        0.3
# Fairbanks: ERA5-4km  -0.06       0.11      0.21     0.14      -0.23
# Fairbanks: PAFA       -0.0       0.19      0.21     0.13      -0.07
#
#                            Jun       Jul        Aug       Sep        Oct  \
# ID
# Anchorage: ERA5-4km      -0.02      0.31      -0.43      0.25      -0.25
# Anchorage: PANC           0.11      0.08      -0.55      0.26      -0.45
# Barrow: ERA5-4km           0.2       0.3      -0.09     -0.05   0.35 (*)
# Barrow: PABR         0.24 (**)      0.16       0.09      0.09  0.26 (**)
# Bethel: ERA5-4km          0.09      0.29      -0.25     -0.39       0.43
# Bethel: PABE               0.2  0.63 (*)       0.22      0.65   0.59 (*)
# Fairbanks: ERA5-4km       0.22      -0.6  0.87 (**)       0.3      -0.08
# Fairbanks: PAFA           0.29      0.54   0.67 (*)  0.48 (*)       -0.2
#
#                            Nov         Dec
# ID
# Anchorage: ERA5-4km       0.29       -0.09
# Anchorage: PANC           0.12        0.23
# Barrow: ERA5-4km     0.49 (**)        0.09
# Barrow: PABR         0.44 (**)    0.2 (**)
# Bethel: ERA5-4km         -0.09  -0.53 (**)
# Bethel: PABE              0.37       -0.21
# Fairbanks: ERA5-4km       0.18       -0.27
# Fairbanks: PAFA           0.19       -0.22
