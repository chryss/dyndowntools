# %%
from pathlib import Path
import xarray as xr
import rioxarray as rxr
import xwrf

# %%
datadir1 = Path("/center1/DYNDOWN/cwaigl/ERA5_WRF/WPS202111_B_nc")
datadir2 = Path("/beegfs/CMIP6/wrf_era5/04km")
yr = "2021"
mth = "11"
day = "11"
hour = "00"
fp2 = "era5_wrf_dscale_4km"
fp1 = "met_em.d02."

testfp = datadir1 / f"{fp1}{yr}-{mth}-{day}_{hour}:00:00.nc" 
testfp2 = datadir2 / f"{yr}/{fp2}_{yr}-{mth}-{day}.nc"

# %%
testds = xr.open_dataset(testfp, decode_coords='all', decode_times=True)
testds = testds.xwrf.postprocess()

# %%
testds
# Out:
# <xarray.Dataset> Size: 326MB
# Dimensions:         (Time: 1, num_metgrid_levels: 38, y: 450, x: 420,
#                      num_st_layers: 4, num_sm_layers: 4, y_stag: 451,
#                      x_stag: 421, z-dimension0012: 12, z-dimension0016: 16,
#                      z-dimension0021: 21)
# Coordinates: (12/15)
#     XLONG_C         (y_stag, x_stag) float32 759kB -165.0 -164.9 ... -128.5
#     XLAT_C          (y_stag, x_stag) float32 759kB 55.11 55.12 ... 70.54 70.53
#     CLONG           (y, x) float32 756kB -164.9 -164.9 -164.8 ... -128.7 -128.6
#     CLAT            (y, x) float32 756kB 55.13 55.14 55.15 ... 70.55 70.53 70.52
#     XLONG_U         (y, x_stag) float32 758kB -165.0 -164.9 ... -128.6 -128.5
#     XLAT_U          (y, x_stag) float32 758kB 55.13 55.14 55.15 ... 70.53 70.51
#     ...              ...
#     XLAT_M          (y, x) float32 756kB 55.13 55.14 55.15 ... 70.55 70.53 70.52
#   * Time            (Time) datetime64[ns] 8B 2021-11-11
#   * x               (x) float64 3kB -8.511e+05 -8.471e+05 ... 8.249e+05
#   * x_stag          (x_stag) float64 3kB -8.531e+05 -8.491e+05 ... 8.269e+05
#   * y               (y) float64 4kB -3.701e+06 -3.697e+06 ... -1.905e+06
#   * y_stag          (y_stag) float64 4kB -3.703e+06 -3.699e+06 ... -1.903e+06
# Dimensions without coordinates: num_metgrid_levels, num_st_layers,
#                                 num_sm_layers, z-dimension0012,
#                                 z-dimension0016, z-dimension0021
# Data variables: (12/72)
#     Times           (Time) |S19 19B b'2021-11-11_00:00:00'
#     PRES            (Time, num_metgrid_levels, y, x) float32 29MB ...
#     SOIL_LAYERS     (Time, num_st_layers, y, x) float32 3MB ...
#     SM              (Time, num_sm_layers, y, x) float32 3MB ...
#     ST              (Time, num_st_layers, y, x) float32 3MB ...
#     SOILHGT         (Time, y, x) float32 756kB ...
#     ...              ...
#     MAPFAC_VX       (Time, y_stag, x) float32 758kB ...
#     MAPFAC_MX       (Time, y, x) float32 756kB ...
#     MAPFAC_U        (Time, y, x_stag) float32 758kB ...
#     MAPFAC_V        (Time, y_stag, x) float32 758kB ...
#     MAPFAC_M        (Time, y, x) float32 756kB ...
#     wrf_projection  object 8B +proj=stere +x_0=0 +y_0=0 +a=6370000 +b=6370000...
# Attributes: (12/117)
#     TITLE:                           OUTPUT FROM METGRID V4.5
#     SIMULATION_START_DATE:           2021-11-11_00:00:00
#     WEST-EAST_GRID_DIMENSION:        421
#     SOUTH-NORTH_GRID_DIMENSION:      451
#     BOTTOM-TOP_GRID_DIMENSION:       38
#     WEST-EAST_PATCH_START_UNSTAG:    1
#     ...                              ...
#     FLAG_OL1:                        1
#     FLAG_OL2:                        1
#     FLAG_OL3:                        1
#     FLAG_OL4:                        1
#     FLAG_VAR_SSO:                    1
#     FLAG_LAKE_DEPTH:                 1

# %%
testds.XLAT_C.attrs
# Out:
# {'FieldType': 104,
#  'MemoryOrder': 'XY ',
#  'units': 'degrees latitude',
#  'description': 'Latitude at grid cell corners',
#  'stagger': 'CORNER',
#  'sr_x': 1,
#  'sr_y': 1}

# %%
testds2 = xr.open_dataset(testfp2, decode_coords='all', decode_times=True)

# %%
testds2
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:       (Time: 24, south_north: 450, west_east: 420, interp_level: 9,
#                    soil_layers_stag: 4)
# Coordinates:
#   * Time          (Time) datetime64[ns] 192B 2021-11-11 ... 2021-11-11T23:00:00
#     XLONG         (south_north, west_east) float32 756kB ...
#     XLAT          (south_north, west_east) float32 756kB ...
#     XTIME         (Time) float32 96B ...
#   * interp_level  (interp_level) float64 72B 200.0 300.0 500.0 ... 950.0 1e+03
# Dimensions without coordinates: south_north, west_east, soil_layers_stag
# Data variables: (12/43)
#     slp           (Time, south_north, west_east) float32 18MB ...
#     ctt           (Time, south_north, west_east) float32 18MB ...
#     dbz           (Time, interp_level, south_north, west_east) float32 163MB ...
#     rh2           (Time, south_north, west_east) float32 18MB ...
#     T2            (Time, south_north, west_east) float32 18MB ...
#     Q2            (Time, south_north, west_east) float32 18MB ...
#     ...            ...
#     u             (Time, interp_level, south_north, west_east) float32 163MB ...
#     v             (Time, interp_level, south_north, west_east) float32 163MB ...
#     w             (Time, interp_level, south_north, west_east) float32 163MB ...
#     rainnc        (Time, south_north, west_east) float32 18MB ...
#     rainc         (Time, south_north, west_east) float32 18MB ...
#     acsnow        (Time, south_north, west_east) float32 18MB ...
# Attributes:
#     date:     2024-01-11T17:34:22.466514
#     data:     Downscaled ERA5 using WRF
#     info:     Alaska Climate Adaptation Science Center, University of Alaska ...
#     contact:  cwaigl@alaska.edu
#     version:  WRF V4.5.1 - project v. 1.1
