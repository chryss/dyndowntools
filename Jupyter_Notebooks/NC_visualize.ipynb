# %%
from pathlib import Path
import numpy as np
import xarray as xr
from matplotlib import pyplot as plt
import cartopy.crs as ccrs
import seaborn as sns

# %%
sns.set_context("talk")

# %%
basedir = Path("/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/")
fn = "v03/met_em.d01.2021-04-01_00:00:00.nc"

# %%
(basedir / fn).exists()
# Out:
# True

# %%
metem = xr.open_dataset(basedir / fn)
metem.SNOW[0].plot(figsize=(15,10))

# %%
fn = "v04/met_em.d01.2021-04-01_00:00:00.nc"
(basedir / fn).exists()
# Out:
# True

# %%
metem = xr.open_dataset(basedir / fn)
metem.SNOW[0].plot(figsize=(15,10))

# %%
fn = "v04/met_em.d02.2021-04-01_00:00:00.nc"

# %%
(basedir / fn).exists()
# Out:
# True

# %%
metem = xr.open_dataset(basedir / fn)
metem.TT[0][0].plot(figsize=(15,10))

# %%
ccrs.Stereographic(
# Out:
# <xarray.Dataset>
# Dimensions:      (Time: 1, num_metgrid_levels: 38, south_north: 450, west_east: 432, num_st_layers: 4, num_sm_layers: 4, south_north_stag: 451, west_east_stag: 433, z-dimension0012: 12, z-dimension0016: 16, z-dimension0021: 21)
# Dimensions without coordinates: Time, num_metgrid_levels, south_north, west_east, num_st_layers, num_sm_layers, south_north_stag, west_east_stag, z-dimension0012, z-dimension0016, z-dimension0021
# Data variables: (12/75)
#     Times        (Time) |S19 ...
#     PRES         (Time, num_metgrid_levels, south_north, west_east) float32 ...
#     SOIL_LAYERS  (Time, num_st_layers, south_north, west_east) float32 ...
#     SM           (Time, num_sm_layers, south_north, west_east) float32 ...
#     ST           (Time, num_st_layers, south_north, west_east) float32 ...
#     GHT          (Time, num_metgrid_levels, south_north, west_east) float32 ...
#     ...           ...
#     XLONG_U      (Time, south_north, west_east_stag) float32 ...
# ...

# %%
wrfdir = Path("/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02")

# %%
fn = "seaiced01.nc"
(wrfdir / fn).exists()
# Out:
# True

# %%
wrf = xr.open_dataset(wrfdir / fn)
wrf.SEAICE[0].plot(figsize=(45,30))

# %%
wrfdir = Path("/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/")

# %%
list(wrfdir.glob('*'))
# Out:
# [PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/t2d02.nc'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/seaiced01.nc'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/td02.nc'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/snowd02.nc'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/snowd01.nc'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/seaiced02.nc'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/td01.nc'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/wrflowinp_d01'),
#  PosixPath('/Users/cwaigl/Projects/2020_firedanger_data/ERA_downscaling/test02/t2d01.nc')]

# %%
fn = "t2d02.nc"
(wrfdir / fn).exists()
# Out:
# True

# %%
wrf = xr.open_dataset(wrfdir / fn)
wrf.T2[0].plot(figsize=(30,20))

# %%
wrf
# Out:
# <xarray.Dataset>
# Dimensions:  (south_north: 450, west_east: 432, XTIME: 22)
# Coordinates:
#     XLONG    (south_north, west_east) float32 ...
#     XLAT     (south_north, west_east) float32 ...
#   * XTIME    (XTIME) datetime64[ns] 2021-06-01 ... 2021-06-01T21:00:00
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     T2       (XTIME, south_north, west_east) float32 ...
# Attributes: (12/135)
#     CDI:                             Climate Data Interface version 1.7.2 (ht...
#     Conventions:                     CF-1.4
#     history:                         Thu Mar 10 11:38:28 2022: cdo select,nam...
#     TITLE:                            OUTPUT FROM *             PROGRAM:WRF-C...
#     START_DATE:                      2021-06-01_00:00:00
#     SIMULATION_START_DATE:           2021-06-01_00:00:00
#     ...                              ...
#     ISICE:                           15
#     ISURBAN:                         13
# ...

# %%
fn = "td01.nc"
(wrfdir / fn).exists()
# Out:
# True

# %%
wrf = xr.open_dataset(wrfdir / fn)
wrf.T[0][0].plot(figsize=(45,30))

# %%
fn = "v01/met_em.d01.2021-04-01_00:00:00.nc"
(basedir / fn).exists()
# Out:
# True

# %%
metem = xr.open_dataset(basedir / fn)
metem.SNOW[0].plot(figsize=(15,10))
