# %%
import datetime as dt
import pandas as pd

# %%
startstr = '221228'
startdate = dt.datetime.strptime(startstr, '%y%m%d').date()
startdate
# Out:
# datetime.date(2022, 12, 28)

# %%
records = []
thisdate = startdate

while True:
    ready = 0
    if thisdate.month in [11, 12]:
        ready = 1
    bridge = 0
    if (
        thisdate.month != (thisdate + dt.timedelta(days=2)).month
        ) or (
        thisdate.month != (thisdate - dt.timedelta(hours=-6)).month):
        bridge = 1
    records.append((thisdate.strftime('%y%m%d'), ready, bridge))
    thisdate = (thisdate - dt.timedelta(days=2))
    if thisdate.year < 2022:
        break

# %%
recordsdf = pd.DataFrame.from_records(records, columns=['datelabel', 'inputready', 'bridgemonth'])
recordsdf['wpssetup'] = '' 
recordsdf['wrfsetup'] = '' 
recordsdf['wrfprocess'] = '' 
recordsdf['filearchive'] = '' 
recordsdf['filepostproc'] = '' 
recordsdf['cleanup'] = ''
recordsdf
# Out:
#     datelabel  inputready  bridgemonth wpssetup wrfsetup wrfprocess  \
# 0      221228           1            0
# 1      221226           1            0
# 2      221224           1            0
# 3      221222           1            0
# 4      221220           1            0
# ..        ...         ...          ...      ...      ...        ...
# 176    220110           0            0
# 177    220108           0            0
# 178    220106           0            0
# 179    220104           0            0
# 180    220102           0            0
#
#     filearchive filepostproc cleanup
# 0
# 1
# 2
# 3
# 4
# ..          ...          ...     ...
# 176
# 177
# 178
# 179
# 180
#
# [181 rows x 9 columns]

# %%
recordsdf.to_feather('status.feather')
